# %%
import json
import asyncio

from aiohttp import ClientSession, BasicAuth
from python_opensky import OpenSky, BoundingBox
from pyensign.ensign import authenticate, publisher

# %% [markdown]
# # Configuration

# %%
OPENSKY_CREDS_PATH="opensky-creds.json"
ENSIGN_CREDS_PATH="flight-tracker-creds.json"

def load_opensky_creds():
    with open(OPENSKY_CREDS_PATH) as f:
        creds = json.load(f)
        return BasicAuth(login=creds["username"], password=creds["password"])

OPENSKY_CREDS = load_opensky_creds()

# %%
BOUNDING_BOX = BoundingBox(
    min_latitude=43,
    max_latitude=49,
    min_longitude=-97,
    max_longitude=-89,
)

INTERVAL_SEC=5

# %% [markdown]
# # Publish Flight Updates

# %%
@publisher("flight-positions")
async def get_flights():
    async with ClientSession() as session:
        async with OpenSky(session=session) as opensky:
            await opensky.authenticate(OPENSKY_CREDS)
            
            response = await opensky.get_states(bounding_box=BOUNDING_BOX)
            for vector in response.states:
                yield {
                    "icao24": vector.icao24,
                    "callsign": vector.callsign,
                    "origin_country": vector.origin_country,
                    "time_position": vector.time_position,
                    "last_contact": vector.last_contact,
                    "longitude": vector.longitude,
                    "latitude": vector.latitude,
                    "geo_altitude": vector.geo_altitude,
                    "on_ground": vector.on_ground,
                    "velocity": vector.velocity,
                    "true_track": vector.true_track,
                    "vertical_rate": vector.vertical_rate,
                    "sensors": vector.sensors,
                    "barometric_altitude": vector.barometric_altitude,
                    "transponder_code": vector.transponder_code,
                    "special_purpose_indicator": vector.special_purpose_indicator,
                    "position_source": vector.position_source,
                    "category": vector.category,
                }
                
@authenticate(cred_path=ENSIGN_CREDS_PATH)
async def poll_flights():
    for i in range(10):
        async for data in get_flights():
            print(data)
        await asyncio.sleep(INTERVAL_SEC)
            
    # Wait for pending events to get published
    await asyncio.sleep(1)

# %%
await poll_flights()
# Out:
# {'icao24': 'acdfab', 'callsign': 'DAL1591 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.8017, 'latitude': 44.8641, 'geo_altitude': 4930.14, 'on_ground': False, 'velocity': 155.47, 'true_track': 264.87, 'vertical_rate': -7.15, 'sensors': None, 'barometric_altitude': 4693.92, 'transponder_code': '3535', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a2355d', 'callsign': 'SKW3851 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -96.7387, 'latitude': 44.5379, 'geo_altitude': 11125.2, 'on_ground': False, 'velocity': 252.83, 'true_track': 85.57, 'vertical_rate': 0.65, 'sensors': None, 'barometric_altitude': 10668.0, 'transponder_code': '3345', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a34268', 'callsign': 'SKW3827 ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271978, 'longitude': -90.5429, 'latitude': 43.8642, 'geo_altitude': 10355.58, 'on_ground': False, 'velocity': 232.3, 'true_track': 118.72, 'vertical_rate': 5.53, 'sensors': None, 'barometric_altitude': 9913.62, 'transponder_code': '2652', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a26a70', 'callsign': 'N255DV  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.4127, 'latitude': 46.7923, 'geo_altitude': 12641.58, 'on_ground': False, 'velocity': 218.35, 'true_track': 310.03, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 12192.0, 'transponder_code': '1301', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.SMALL: 3>}
# {'icao24': 'a5f7e9', 'callsign': 'N484ER  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -89.3158, 'latitude': 43.1677, 'geo_altitude': 350.52, 'on_ground': False, 'velocity': 38.73, 'true_track': 210.31, 'vertical_rate': -1.3, 'sensors': None, 'barometric_altitude': 320.04, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c046f4', 'callsign': 'AM187   ', 'origin_country': 'Canada', 'time_position': 1696271957, 'last_contact': 1696271957, 'longitude': -89.3114, 'latitude': 48.3733, 'geo_altitude': None, 'on_ground': True, 'velocity': 3.6, 'true_track': 149.06, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.SMALL: 3>}
# {'icao24': 'a60631', 'callsign': 'N4879D  ', 'origin_country': 'United States', 'time_position': 1696271974, 'last_contact': 1696271978, 'longitude': -89.7747, 'latitude': 43.2061, 'geo_altitude': 1150.62, 'on_ground': False, 'velocity': 50.66, 'true_track': 304.66, 'vertical_rate': 2.6, 'sensors': None, 'barometric_altitude': 1097.28, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a46368', 'callsign': 'HAL89   ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.2853, 'latitude': 43.4478, 'geo_altitude': 11490.96, 'on_ground': False, 'velocity': 234.97, 'true_track': 275.02, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '7500', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a71343', 'callsign': 'N555P   ', 'origin_country': 'United States', 'time_position': 1696271688, 'last_contact': 1696271688, 'longitude': -89.2481, 'latitude': 43.9701, 'geo_altitude': 617.22, 'on_ground': False, 'velocity': 87.9, 'true_track': 334.33, 'vertical_rate': -0.98, 'sensors': None, 'barometric_altitude': 586.74, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a605f0', 'callsign': 'N4877J  ', 'origin_country': 'United States', 'time_position': 1696271976, 'last_contact': 1696271976, 'longitude': -93.4721, 'latitude': 44.7288, 'geo_altitude': 899.16, 'on_ground': False, 'velocity': 40.09, 'true_track': 188.86, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 876.3, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '781a4b', 'callsign': 'CKK228  ', 'origin_country': 'China', 'time_position': 1696271842, 'last_contact': 1696271842, 'longitude': -93.0662, 'latitude': 48.0932, 'geo_altitude': 9509.76, 'on_ground': False, 'velocity': 248.6, 'true_track': 335.29, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9144.0, 'transponder_code': '1372', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a39e5a', 'callsign': 'MVK25   ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -93.6076, 'latitude': 44.2195, 'geo_altitude': 1668.78, 'on_ground': False, 'velocity': 37.23, 'true_track': 78.85, 'vertical_rate': 1.3, 'sensors': None, 'barometric_altitude': 1592.58, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a14ae4', 'callsign': 'N1823J  ', 'origin_country': 'United States', 'time_position': 1696271835, 'last_contact': 1696271835, 'longitude': -93.454, 'latitude': 44.8317, 'geo_altitude': 297.18, 'on_ground': False, 'velocity': 31.49, 'true_track': 184.69, 'vertical_rate': -3.25, 'sensors': None, 'barometric_altitude': 297.18, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a3401a', 'callsign': 'JBU836  ', 'origin_country': 'United States', 'time_position': 1696271818, 'last_contact': 1696271818, 'longitude': -93.2272, 'latitude': 44.8758, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.06, 'true_track': 135.0, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '3032', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a365b7', 'callsign': 'DAL2422 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.2359, 'latitude': 44.8864, 'geo_altitude': None, 'on_ground': True, 'velocity': 7.72, 'true_track': 298.12, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '2640', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a65e8c', 'callsign': 'N5096C  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -93.4575, 'latitude': 44.8113, 'geo_altitude': 518.16, 'on_ground': False, 'velocity': 30.98, 'true_track': 144.46, 'vertical_rate': 2.28, 'sensors': None, 'barometric_altitude': 502.92, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'aa2ded', 'callsign': 'N755PM  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.2902, 'latitude': 44.7552, 'geo_altitude': 762.0, 'on_ground': False, 'velocity': 87.22, 'true_track': 13.3, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 723.9, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a57339', 'callsign': 'MVK92   ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -93.6311, 'latitude': 44.3908, 'geo_altitude': 922.02, 'on_ground': False, 'velocity': 53.08, 'true_track': 236.46, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 899.16, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac141f', 'callsign': 'SKW4242 ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271978, 'longitude': -90.5439, 'latitude': 45.5374, 'geo_altitude': 9425.94, 'on_ground': False, 'velocity': 220.15, 'true_track': 78.27, 'vertical_rate': 2.6, 'sensors': None, 'barometric_altitude': 9022.08, 'transponder_code': '2665', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a5613e', 'callsign': 'N446DM  ', 'origin_country': 'United States', 'time_position': 1696271961, 'last_contact': 1696271961, 'longitude': -92.3804, 'latitude': 45.3911, 'geo_altitude': 906.78, 'on_ground': False, 'velocity': 71.04, 'true_track': 177.92, 'vertical_rate': -1.3, 'sensors': None, 'barometric_altitude': 876.3, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a0e6c4', 'callsign': 'UAL1310 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -90.8023, 'latitude': 44.4583, 'geo_altitude': 10210.8, 'on_ground': False, 'velocity': 218.4, 'true_track': 292.58, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9753.6, 'transponder_code': '4224', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'ab4ea8', 'callsign': 'AAL2104 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.0303, 'latitude': 44.7838, 'geo_altitude': 2278.38, 'on_ground': False, 'velocity': 144.25, 'true_track': 116.47, 'vertical_rate': 17.23, 'sensors': None, 'barometric_altitude': 2209.8, 'transponder_code': '3605', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a26f6f', 'callsign': 'SKW3945 ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -93.2114, 'latitude': 44.8869, 'geo_altitude': None, 'on_ground': True, 'velocity': 5.66, 'true_track': 298.12, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '3614', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'aae810', 'callsign': 'SCX3050 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.2435, 'latitude': 44.8866, 'geo_altitude': None, 'on_ground': True, 'velocity': 8.75, 'true_track': 348.75, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'aad3c9', 'callsign': 'UAL803  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -89.5289, 'latitude': 47.1412, 'geo_altitude': 10172.7, 'on_ground': False, 'velocity': 245.95, 'true_track': 318.31, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9753.6, 'transponder_code': '6504', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a03f24', 'callsign': 'DAL1645 ', 'origin_country': 'United States', 'time_position': 1696271933, 'last_contact': 1696271939, 'longitude': -93.2283, 'latitude': 44.8636, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.13, 'true_track': 357.19, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a583a8', 'callsign': 'N4542T  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.6052, 'latitude': 45.0283, 'geo_altitude': 1394.46, 'on_ground': False, 'velocity': 62.76, 'true_track': 165.28, 'vertical_rate': 0.98, 'sensors': None, 'barometric_altitude': 1310.64, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a76f46', 'callsign': 'UAL1606 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.7636, 'latitude': 43.0479, 'geo_altitude': 10203.18, 'on_ground': False, 'velocity': 228.87, 'true_track': 280.1, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9753.6, 'transponder_code': '2433', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a4a0cd', 'callsign': 'DAL2622 ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -93.2814, 'latitude': 44.9082, 'geo_altitude': 480.06, 'on_ground': False, 'velocity': 80.38, 'true_track': 121.66, 'vertical_rate': -4.55, 'sensors': None, 'barometric_altitude': 457.2, 'transponder_code': '2402', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab03a4', 'callsign': 'DAL2758 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -96.7696, 'latitude': 43.5901, 'geo_altitude': 11132.82, 'on_ground': False, 'velocity': 259.9, 'true_track': 57.69, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10660.38, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a34592', 'callsign': 'CSJ213  ', 'origin_country': 'United States', 'time_position': 1696271955, 'last_contact': 1696271955, 'longitude': -93.2831, 'latitude': 43.3043, 'geo_altitude': 1844.04, 'on_ground': False, 'velocity': 99.63, 'true_track': 279.51, 'vertical_rate': 0.98, 'sensors': None, 'barometric_altitude': 1760.22, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a9b806', 'callsign': 'TIV725  ', 'origin_country': 'United States', 'time_position': 1696271965, 'last_contact': 1696271968, 'longitude': -93.0392, 'latitude': 43.854, 'geo_altitude': 13540.74, 'on_ground': False, 'velocity': 214.13, 'true_track': 265.59, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 13106.4, 'transponder_code': '3533', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab3a49', 'callsign': 'N822WM  ', 'origin_country': 'United States', 'time_position': 1696271868, 'last_contact': 1696271868, 'longitude': -90.8998, 'latitude': 44.8105, 'geo_altitude': 3314.7, 'on_ground': False, 'velocity': 91.8, 'true_track': 333.0, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 3154.68, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a4fd96', 'callsign': 'N420WC  ', 'origin_country': 'United States', 'time_position': 1696271943, 'last_contact': 1696271952, 'longitude': -92.8067, 'latitude': 44.9617, 'geo_altitude': 327.66, 'on_ground': False, 'velocity': 13.42, 'true_track': 85.6, 'vertical_rate': -2.93, 'sensors': None, 'barometric_altitude': 320.04, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c010ec', 'callsign': 'ACA738  ', 'origin_country': 'Canada', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -96.384, 'latitude': 43.3402, 'geo_altitude': 11148.06, 'on_ground': False, 'velocity': 257.13, 'true_track': 83.91, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10668.0, 'transponder_code': '3305', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a2261e', 'callsign': 'N2379K  ', 'origin_country': 'United States', 'time_position': 1696271858, 'last_contact': 1696271866, 'longitude': -92.9823, 'latitude': 44.4238, 'geo_altitude': 891.54, 'on_ground': False, 'velocity': 57.1, 'true_track': 18.92, 'vertical_rate': -3.9, 'sensors': None, 'barometric_altitude': 853.44, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a767f3', 'callsign': 'N5766X  ', 'origin_country': 'United States', 'time_position': 1696271966, 'last_contact': 1696271968, 'longitude': -89.3535, 'latitude': 43.6421, 'geo_altitude': 2484.12, 'on_ground': False, 'velocity': 68.11, 'true_track': 201.72, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 2369.82, 'transponder_code': '1634', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a3866d', 'callsign': 'DAL2405 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.309, 'latitude': 44.5853, 'geo_altitude': 5227.32, 'on_ground': False, 'velocity': 212.46, 'true_track': 111.6, 'vertical_rate': 9.1, 'sensors': None, 'barometric_altitude': 4983.48, 'transponder_code': '2451', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a05b78', 'callsign': 'DAL1357 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -91.318, 'latitude': 44.1087, 'geo_altitude': 7749.54, 'on_ground': False, 'velocity': 248.5, 'true_track': 115.77, 'vertical_rate': 5.2, 'sensors': None, 'barometric_altitude': 7376.16, 'transponder_code': '3620', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a265b8', 'callsign': 'N2535P  ', 'origin_country': 'United States', 'time_position': 1696271964, 'last_contact': 1696271964, 'longitude': -89.5342, 'latitude': 43.113, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.0, 'true_track': 2.81, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'aba965', 'callsign': 'N850X   ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -95.728, 'latitude': 44.7008, 'geo_altitude': 4754.88, 'on_ground': False, 'velocity': 134.31, 'true_track': 190.15, 'vertical_rate': -2.28, 'sensors': None, 'barometric_altitude': 4541.52, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a55e4d', 'callsign': 'MVK82   ', 'origin_country': 'United States', 'time_position': 1696271974, 'last_contact': 1696271974, 'longitude': -94.5812, 'latitude': 44.6165, 'geo_altitude': 1485.9, 'on_ground': False, 'velocity': 45.38, 'true_track': 176.1, 'vertical_rate': -2.28, 'sensors': None, 'barometric_altitude': 1432.56, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a982b1', 'callsign': 'N7114J  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.7598, 'latitude': 45.0209, 'geo_altitude': 807.72, 'on_ground': False, 'velocity': 59.66, 'true_track': 330.56, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 800.1, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '71c011', 'callsign': 'KAL038  ', 'origin_country': 'Republic of Korea', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -94.301, 'latitude': 48.2902, 'geo_altitude': 10142.22, 'on_ground': False, 'velocity': 244.69, 'true_track': 317.56, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9753.6, 'transponder_code': '3157', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a982c4', 'callsign': 'N71143  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271978, 'longitude': -93.2398, 'latitude': 44.6323, 'geo_altitude': 365.76, 'on_ground': False, 'velocity': 44.56, 'true_track': 121.3, 'vertical_rate': 2.6, 'sensors': None, 'barometric_altitude': 365.76, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a982c2', 'callsign': 'N71141  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.6381, 'latitude': 44.5771, 'geo_altitude': 952.5, 'on_ground': False, 'velocity': 47.37, 'true_track': 182.49, 'vertical_rate': -1.63, 'sensors': None, 'barometric_altitude': 929.64, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '71c005', 'callsign': 'KAL8232 ', 'origin_country': 'Republic of Korea', 'time_position': 1696271962, 'last_contact': 1696271962, 'longitude': -93.1353, 'latitude': 47.6603, 'geo_altitude': 11399.52, 'on_ground': False, 'velocity': 238.19, 'true_track': 323.25, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': '3123', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a00133', 'callsign': 'N1NE    ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -96.96, 'latitude': 45.2772, 'geo_altitude': 12633.96, 'on_ground': False, 'velocity': 235.73, 'true_track': 271.75, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 12176.76, 'transponder_code': '5546', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'ac9c39', 'callsign': 'N911UW  ', 'origin_country': 'United States', 'time_position': 1696271781, 'last_contact': 1696271781, 'longitude': -89.4318, 'latitude': 43.0763, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.06, 'true_track': 289.69, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a1df00', 'callsign': 'N22DN   ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.9173, 'latitude': 43.6607, 'geo_altitude': 1348.74, 'on_ground': False, 'velocity': 88.04, 'true_track': 109.81, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 1318.26, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a9e5ea', 'callsign': 'N737JX  ', 'origin_country': 'United States', 'time_position': 1696271975, 'last_contact': 1696271975, 'longitude': -93.9521, 'latitude': 44.7904, 'geo_altitude': 1036.32, 'on_ground': False, 'velocity': 56.16, 'true_track': 65.08, 'vertical_rate': 1.63, 'sensors': None, 'barometric_altitude': 1013.46, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a9e745', 'callsign': 'N737YU  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.8356, 'latitude': 45.3464, 'geo_altitude': 1074.42, 'on_ground': False, 'velocity': 61.35, 'true_track': 342.93, 'vertical_rate': -1.3, 'sensors': None, 'barometric_altitude': 1043.94, 'transponder_code': '1347', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'adb13b', 'callsign': 'N9810H  ', 'origin_country': 'United States', 'time_position': 1696271976, 'last_contact': 1696271978, 'longitude': -89.8672, 'latitude': 43.1689, 'geo_altitude': 876.3, 'on_ground': False, 'velocity': 61.3, 'true_track': 87.11, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 822.96, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a3e9a1', 'callsign': 'MVK53   ', 'origin_country': 'United States', 'time_position': 1696271876, 'last_contact': 1696271876, 'longitude': -93.9132, 'latitude': 44.2231, 'geo_altitude': 297.18, 'on_ground': False, 'velocity': 29.52, 'true_track': 228.53, 'vertical_rate': -3.9, 'sensors': None, 'barometric_altitude': 297.18, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac5442', 'callsign': 'DAL2696 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.6472, 'latitude': 44.8664, 'geo_altitude': 5364.48, 'on_ground': False, 'velocity': 173.92, 'true_track': 268.81, 'vertical_rate': -9.75, 'sensors': None, 'barometric_altitude': 5105.4, 'transponder_code': '6262', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a97172', 'callsign': 'N70739  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -89.6321, 'latitude': 43.092, 'geo_altitude': 609.6, 'on_ground': False, 'velocity': 52.47, 'true_track': 90.0, 'vertical_rate': -2.28, 'sensors': None, 'barometric_altitude': 579.12, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a67b75', 'callsign': 'JIA5633 ', 'origin_country': 'United States', 'time_position': 1696271968, 'last_contact': 1696271978, 'longitude': -89.3342, 'latitude': 43.141, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.0, 'true_track': 28.12, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab7a21', 'callsign': 'DAL824  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -94.4537, 'latitude': 44.2602, 'geo_altitude': 6957.06, 'on_ground': False, 'velocity': 228.72, 'true_track': 233.41, 'vertical_rate': 10.08, 'sensors': None, 'barometric_altitude': 6652.26, 'transponder_code': '2425', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a3d4b5', 'callsign': 'MVK43   ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -93.8285, 'latitude': 44.1979, 'geo_altitude': 609.6, 'on_ground': False, 'velocity': 49.14, 'true_track': 259.75, 'vertical_rate': 0.98, 'sensors': None, 'barometric_altitude': 601.98, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a11106', 'callsign': 'N168SR  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -89.303, 'latitude': 43.1487, 'geo_altitude': 571.5, 'on_ground': False, 'velocity': 58.08, 'true_track': 32.7, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 487.68, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a0044b', 'callsign': 'N10VW   ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271978, 'longitude': -93.0799, 'latitude': 44.9254, 'geo_altitude': 9867.9, 'on_ground': False, 'velocity': 170.05, 'true_track': 112.22, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9448.8, 'transponder_code': '3662', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab120b', 'callsign': 'DAL163  ', 'origin_country': 'United States', 'time_position': 1696271959, 'last_contact': 1696271959, 'longitude': -90.1834, 'latitude': 48.8753, 'geo_altitude': 11963.4, 'on_ground': False, 'velocity': 213.45, 'true_track': 214.0, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 11582.4, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.HEAVY: 6>}
# {'icao24': 'a3fc1c', 'callsign': 'N356LL  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.0413, 'latitude': 45.1403, 'geo_altitude': 746.76, 'on_ground': False, 'velocity': 72.72, 'true_track': 85.94, 'vertical_rate': -1.63, 'sensors': None, 'barometric_altitude': 723.9, 'transponder_code': '2776', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.ROTORCRAFT: 8>}
# {'icao24': 'a8eae8', 'callsign': 'N674DJ  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -91.6957, 'latitude': 46.7305, 'geo_altitude': 11224.26, 'on_ground': False, 'velocity': 189.61, 'true_track': 148.42, 'vertical_rate': 5.2, 'sensors': None, 'barometric_altitude': 10767.06, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a3fc34', 'callsign': 'MVK63   ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -96.0803, 'latitude': 44.7256, 'geo_altitude': 1363.98, 'on_ground': False, 'velocity': 38.73, 'true_track': 106.99, 'vertical_rate': 6.83, 'sensors': None, 'barometric_altitude': 1325.88, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab7f3f', 'callsign': 'N84TX   ', 'origin_country': 'United States', 'time_position': 1696271971, 'last_contact': 1696271978, 'longitude': -96.8923, 'latitude': 46.868, 'geo_altitude': 1097.28, 'on_ground': False, 'velocity': 54.23, 'true_track': 226.92, 'vertical_rate': 4.88, 'sensors': None, 'barometric_altitude': 1066.8, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'acef2d', 'callsign': 'EDV5201 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -91.602, 'latitude': 44.693, 'geo_altitude': 9265.92, 'on_ground': False, 'velocity': 211.22, 'true_track': 291.88, 'vertical_rate': -10.08, 'sensors': None, 'barometric_altitude': 8854.44, 'transponder_code': '1544', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a42efc', 'callsign': 'DAL2257 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.4903, 'latitude': 45.1382, 'geo_altitude': 1600.2, 'on_ground': False, 'velocity': 124.76, 'true_track': 173.61, 'vertical_rate': -3.25, 'sensors': None, 'barometric_altitude': 1516.38, 'transponder_code': '0453', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a6abae', 'callsign': 'N529PM  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271978, 'longitude': -93.4512, 'latitude': 44.8516, 'geo_altitude': 502.92, 'on_ground': False, 'velocity': 48.87, 'true_track': 179.4, 'vertical_rate': -3.25, 'sensors': None, 'barometric_altitude': 487.68, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a3b4a4', 'callsign': 'MVK33   ', 'origin_country': 'United States', 'time_position': 1696271975, 'last_contact': 1696271975, 'longitude': -92.4192, 'latitude': 45.0377, 'geo_altitude': 830.58, 'on_ground': False, 'velocity': 51.14, 'true_track': 323.59, 'vertical_rate': 0.98, 'sensors': None, 'barometric_altitude': 807.72, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a88a11', 'callsign': 'N64971  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.7704, 'latitude': 44.7732, 'geo_altitude': 1120.14, 'on_ground': False, 'velocity': 24.83, 'true_track': 166.83, 'vertical_rate': -0.98, 'sensors': None, 'barometric_altitude': 1066.8, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a1dead', 'callsign': 'N22AE   ', 'origin_country': 'United States', 'time_position': 1696271963, 'last_contact': 1696271968, 'longitude': -94.2072, 'latitude': 44.5884, 'geo_altitude': 2369.82, 'on_ground': False, 'velocity': 83.61, 'true_track': 85.41, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 2270.76, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a8d9ff', 'callsign': 'N67GK   ', 'origin_country': 'United States', 'time_position': 1696271965, 'last_contact': 1696271974, 'longitude': -92.2246, 'latitude': 44.7273, 'geo_altitude': 2362.2, 'on_ground': False, 'velocity': 70.98, 'true_track': 132.94, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 2232.66, 'transponder_code': '2673', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a6388d', 'callsign': 'N50KW   ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.1351, 'latitude': 45.2408, 'geo_altitude': 670.56, 'on_ground': False, 'velocity': 57.65, 'true_track': 267.95, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 670.56, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a3d86c', 'callsign': 'MVK45   ', 'origin_country': 'United States', 'time_position': 1696271903, 'last_contact': 1696271903, 'longitude': -94.1982, 'latitude': 44.0993, 'geo_altitude': 1089.66, 'on_ground': False, 'velocity': 67.72, 'true_track': 354.33, 'vertical_rate': -10.4, 'sensors': None, 'barometric_altitude': 777.24, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'abcd6b', 'callsign': 'N86KM   ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -94.1864, 'latitude': 45.7351, 'geo_altitude': 12031.98, 'on_ground': False, 'velocity': 195.09, 'true_track': 292.64, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 11582.4, 'transponder_code': '4241', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'acb81f', 'callsign': 'N919AE  ', 'origin_country': 'United States', 'time_position': 1696271976, 'last_contact': 1696271978, 'longitude': -89.3332, 'latitude': 43.1414, 'geo_altitude': 228.6, 'on_ground': False, 'velocity': 16.02, 'true_track': 137.6, 'vertical_rate': 0.33, 'sensors': None, 'barometric_altitude': 190.5, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a30d6b', 'callsign': 'SKW4152 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -89.4846, 'latitude': 43.8682, 'geo_altitude': 10850.88, 'on_ground': False, 'velocity': 200.63, 'true_track': 301.37, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10363.2, 'transponder_code': '4101', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a14956', 'callsign': 'N182NR  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -89.6076, 'latitude': 43.1459, 'geo_altitude': 2164.08, 'on_ground': False, 'velocity': 57.43, 'true_track': 260.2, 'vertical_rate': -5.85, 'sensors': None, 'barometric_altitude': 2065.02, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c066a8', 'callsign': 'CGMWT   ', 'origin_country': 'Canada', 'time_position': 1696271846, 'last_contact': 1696271846, 'longitude': -89.318, 'latitude': 48.3734, 'geo_altitude': None, 'on_ground': True, 'velocity': 4.37, 'true_track': 171.56, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c0307c', 'callsign': 'ACA760  ', 'origin_country': 'Canada', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -89.5232, 'latitude': 46.9926, 'geo_altitude': 11719.56, 'on_ground': False, 'velocity': 251.64, 'true_track': 91.41, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 11277.6, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a6aa5b', 'callsign': 'N52899  ', 'origin_country': 'United States', 'time_position': 1696271974, 'last_contact': 1696271977, 'longitude': -95.7532, 'latitude': 44.1505, 'geo_altitude': 1104.9, 'on_ground': False, 'velocity': 69.71, 'true_track': 63.25, 'vertical_rate': -4.23, 'sensors': None, 'barometric_altitude': 1089.66, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a65a7a', 'callsign': 'N5083S  ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -92.6633, 'latitude': 45.3477, 'geo_altitude': 1188.72, 'on_ground': False, 'velocity': 49.31, 'true_track': 203.36, 'vertical_rate': -0.65, 'sensors': None, 'barometric_altitude': 1127.76, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a80fe5', 'callsign': 'N61879  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -92.9063, 'latitude': 44.9157, 'geo_altitude': 746.76, 'on_ground': False, 'velocity': 33.91, 'true_track': 202.29, 'vertical_rate': 1.3, 'sensors': None, 'barometric_altitude': 723.9, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a388a9', 'callsign': 'DAL1452 ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271978, 'longitude': -92.9113, 'latitude': 44.6329, 'geo_altitude': 3063.24, 'on_ground': False, 'velocity': 151.58, 'true_track': 131.7, 'vertical_rate': 10.08, 'sensors': None, 'barometric_altitude': 2933.7, 'transponder_code': '2431', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a8ea83', 'callsign': 'N6739U  ', 'origin_country': 'United States', 'time_position': 1696271615, 'last_contact': 1696271696, 'longitude': -91.6465, 'latitude': 44.5024, 'geo_altitude': 2819.4, 'on_ground': False, 'velocity': 91.34, 'true_track': 46.6, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 2689.86, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a3c5d9', 'callsign': 'MVK37   ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -93.6912, 'latitude': 44.1223, 'geo_altitude': 1645.92, 'on_ground': False, 'velocity': 44.03, 'true_track': 59.84, 'vertical_rate': 3.25, 'sensors': None, 'barometric_altitude': 1569.72, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a8a319', 'callsign': 'AAL1756 ', 'origin_country': 'United States', 'time_position': 1696271695, 'last_contact': 1696271697, 'longitude': -93.2142, 'latitude': 44.8857, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.0, 'true_track': 129.38, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': 220.98, 'transponder_code': '1671', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c01b5f', 'callsign': 'CFKJM   ', 'origin_country': 'Canada', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -89.1082, 'latitude': 48.4935, 'geo_altitude': 1249.68, 'on_ground': False, 'velocity': 100.79, 'true_track': 67.49, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 1211.58, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'acd486', 'callsign': 'DAL1501 ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -92.0257, 'latitude': 44.8098, 'geo_altitude': 8458.2, 'on_ground': False, 'velocity': 206.65, 'true_track': 291.01, 'vertical_rate': -12.03, 'sensors': None, 'barometric_altitude': 8069.58, 'transponder_code': '3517', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a0311d', 'callsign': 'DAL2745 ', 'origin_country': 'United States', 'time_position': 1696271978, 'last_contact': 1696271978, 'longitude': -90.3094, 'latitude': 44.7596, 'geo_altitude': 11460.48, 'on_ground': False, 'velocity': 219.03, 'true_track': 287.07, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 10965.18, 'transponder_code': '7135', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab0dcb', 'callsign': 'N811HJ  ', 'origin_country': 'United States', 'time_position': 1696271947, 'last_contact': 1696271961, 'longitude': -93.765, 'latitude': 46.5356, 'geo_altitude': 4122.42, 'on_ground': False, 'velocity': 122.97, 'true_track': 0.96, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 3954.78, 'transponder_code': '1200', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ad072a', 'callsign': 'DAL2109 ', 'origin_country': 'United States', 'time_position': 1696271976, 'last_contact': 1696271977, 'longitude': -93.2422, 'latitude': 44.8874, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.32, 'true_track': 171.56, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '3644', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a4aae0', 'callsign': '', 'origin_country': 'United States', 'time_position': 1696271833, 'last_contact': 1696271848, 'longitude': -91.2249, 'latitude': 46.7263, 'geo_altitude': 5356.86, 'on_ground': False, 'velocity': 110.38, 'true_track': 121.47, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 5143.5, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a3f436', 'callsign': 'FFT484  ', 'origin_country': 'United States', 'time_position': 1696271968, 'last_contact': 1696271968, 'longitude': -89.3422, 'latitude': 43.1338, 'geo_altitude': None, 'on_ground': True, 'velocity': 6.94, 'true_track': 278.44, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '6332', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab6493', 'callsign': 'N833MA  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271978, 'longitude': -89.7455, 'latitude': 43.1596, 'geo_altitude': 853.44, 'on_ground': False, 'velocity': 62.64, 'true_track': 345.74, 'vertical_rate': -2.93, 'sensors': None, 'barometric_altitude': 792.48, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a90467', 'callsign': 'N680ND  ', 'origin_country': 'United States', 'time_position': 1696271977, 'last_contact': 1696271977, 'longitude': -96.8193, 'latitude': 44.3069, 'geo_altitude': None, 'on_ground': True, 'velocity': 3.86, 'true_track': 298.12, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '3620', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# ...
# {'icao24': 'c01dcb', 'callsign': 'FLE637  ', 'origin_country': 'Canada', 'time_position': 1696271859, 'last_contact': 1696271861, 'longitude': -90.885, 'latitude': 48.6549, 'geo_altitude': 11376.66, 'on_ground': False, 'velocity': 218.29, 'true_track': 292.15, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 10972.8, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'aa59d8', 'callsign': 'N766WT  ', 'origin_country': 'United States', 'time_position': 1696272042, 'last_contact': 1696272042, 'longitude': -93.336, 'latitude': 46.9052, 'geo_altitude': 4968.24, 'on_ground': False, 'velocity': 128.87, 'true_track': 93.66, 'vertical_rate': -7.15, 'sensors': None, 'barometric_altitude': 4785.36, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ab4151', 'callsign': 'SKW3893 ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -92.7916, 'latitude': 43.9641, 'geo_altitude': 2819.4, 'on_ground': False, 'velocity': 118.73, 'true_track': 304.59, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 2689.86, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a309c8', 'callsign': 'N295TT  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -94.9762, 'latitude': 44.5472, 'geo_altitude': 1996.44, 'on_ground': False, 'velocity': 46.94, 'true_track': 296.0, 'vertical_rate': 0.65, 'sensors': None, 'barometric_altitude': 1920.24, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'c06080', 'callsign': 'ACA113  ', 'origin_country': 'Canada', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -91.5331, 'latitude': 45.5015, 'geo_altitude': 10835.64, 'on_ground': False, 'velocity': 224.35, 'true_track': 290.68, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10370.82, 'transponder_code': '0510', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a0d6a8', 'callsign': 'EDV5438 ', 'origin_country': 'United States', 'time_position': 1696271996, 'last_contact': 1696272009, 'longitude': -89.3446, 'latitude': 43.1364, 'geo_altitude': None, 'on_ground': True, 'velocity': 3.34, 'true_track': 272.81, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '3026', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a0b0c8', 'callsign': 'N1434Q  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -93.7964, 'latitude': 44.1739, 'geo_altitude': 2042.16, 'on_ground': False, 'velocity': 43.29, 'true_track': 200.16, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 1950.72, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac181d', 'callsign': 'DAL729  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -93.3427, 'latitude': 44.9347, 'geo_altitude': 792.48, 'on_ground': False, 'velocity': 92.02, 'true_track': 120.58, 'vertical_rate': -4.23, 'sensors': None, 'barometric_altitude': 754.38, 'transponder_code': '3437', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'aa0cc1', 'callsign': 'N747CD  ', 'origin_country': 'United States', 'time_position': 1696272041, 'last_contact': 1696272041, 'longitude': -89.5303, 'latitude': 43.1125, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.06, 'true_track': 101.25, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a18380', 'callsign': 'EDV5342 ', 'origin_country': 'United States', 'time_position': 1696272041, 'last_contact': 1696272046, 'longitude': -89.343, 'latitude': 43.1397, 'geo_altitude': None, 'on_ground': True, 'velocity': 6.94, 'true_track': 357.19, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a9eec0', 'callsign': 'N739ZG  ', 'origin_country': 'United States', 'time_position': 1696271880, 'last_contact': 1696271880, 'longitude': -92.7586, 'latitude': 44.6016, 'geo_altitude': 967.74, 'on_ground': False, 'velocity': 55.57, 'true_track': 88.94, 'vertical_rate': -2.93, 'sensors': None, 'barometric_altitude': 914.4, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a3cd6b', 'callsign': 'DAL1341 ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -96.8825, 'latitude': 43.6078, 'geo_altitude': 11140.44, 'on_ground': False, 'velocity': 260.51, 'true_track': 50.37, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 10668.0, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a9dcbe', 'callsign': 'N7343X  ', 'origin_country': 'United States', 'time_position': 1696271868, 'last_contact': 1696271871, 'longitude': -93.2097, 'latitude': 45.1622, 'geo_altitude': 327.66, 'on_ground': False, 'velocity': 25.21, 'true_track': 181.17, 'vertical_rate': -0.98, 'sensors': None, 'barometric_altitude': 327.66, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '86e3ec', 'callsign': 'JAL9    ', 'origin_country': 'Japan', 'time_position': 1696272045, 'last_contact': 1696272046, 'longitude': -96.465, 'latitude': 47.435, 'geo_altitude': 10759.44, 'on_ground': False, 'velocity': 248.74, 'true_track': 304.81, 'vertical_rate': -0.33, 'sensors': None, 'barometric_altitude': 10363.2, 'transponder_code': '7233', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.HEAVY: 6>}
# {'icao24': 'a22a07', 'callsign': 'ATN3444 ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -94.3457, 'latitude': 43.1937, 'geo_altitude': 10805.16, 'on_ground': False, 'velocity': 224.02, 'true_track': 285.31, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 10363.2, 'transponder_code': '6515', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a22a01', 'callsign': 'CXK487  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -94.2014, 'latitude': 45.1758, 'geo_altitude': 1851.66, 'on_ground': False, 'velocity': 58.76, 'true_track': 183.51, 'vertical_rate': -1.95, 'sensors': None, 'barometric_altitude': 1798.32, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'aa405f', 'callsign': 'N76ND   ', 'origin_country': 'United States', 'time_position': 1696271862, 'last_contact': 1696271862, 'longitude': -96.7317, 'latitude': 46.8894, 'geo_altitude': 754.38, 'on_ground': False, 'velocity': 90.87, 'true_track': 38.1, 'vertical_rate': 3.58, 'sensors': None, 'barometric_altitude': 784.86, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a9ceba', 'callsign': 'N73093  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -95.1362, 'latitude': 44.6485, 'geo_altitude': 1478.28, 'on_ground': False, 'velocity': 43.26, 'true_track': 177.27, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 1432.56, 'transponder_code': '2521', 'special_purpose_indicator': True, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a35e66', 'callsign': 'AAL2147 ', 'origin_country': 'United States', 'time_position': 1696272017, 'last_contact': 1696272022, 'longitude': -93.2138, 'latitude': 44.886, 'geo_altitude': None, 'on_ground': True, 'velocity': 0.0, 'true_track': 132.19, 'vertical_rate': None, 'sensors': None, 'barometric_altitude': None, 'transponder_code': '0572', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a05410', 'callsign': 'DAL441  ', 'origin_country': 'United States', 'time_position': 1696272045, 'last_contact': 1696272045, 'longitude': -92.2314, 'latitude': 44.0386, 'geo_altitude': 11788.14, 'on_ground': False, 'velocity': 246.24, 'true_track': 102.67, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 11269.98, 'transponder_code': '6652', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a1c441', 'callsign': 'N2127D  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -94.3464, 'latitude': 44.8106, 'geo_altitude': 716.28, 'on_ground': False, 'velocity': 53.67, 'true_track': 330.73, 'vertical_rate': -2.6, 'sensors': None, 'barometric_altitude': 693.42, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': '71be33', 'callsign': 'KAL036  ', 'origin_country': 'Republic of Korea', 'time_position': 1696272045, 'last_contact': 1696272046, 'longitude': -96.9451, 'latitude': 43.1108, 'geo_altitude': 10210.8, 'on_ground': False, 'velocity': 247.79, 'true_track': 311.63, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 9753.6, 'transponder_code': '6004', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac92b1', 'callsign': 'EDV5277 ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -93.8696, 'latitude': 45.8094, 'geo_altitude': 6065.52, 'on_ground': False, 'velocity': 202.95, 'true_track': 115.53, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 5791.2, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_ADS_INFORMATION: 1>}
# {'icao24': 'a41144', 'callsign': 'DAL2304 ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -90.7693, 'latitude': 43.9146, 'geo_altitude': 8862.06, 'on_ground': False, 'velocity': 255.61, 'true_track': 116.15, 'vertical_rate': 5.2, 'sensors': None, 'barometric_altitude': 8450.58, 'transponder_code': '2617', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a60b89', 'callsign': 'N489RK  ', 'origin_country': 'United States', 'time_position': 1696272045, 'last_contact': 1696272046, 'longitude': -89.1186, 'latitude': 44.8504, 'geo_altitude': 4419.6, 'on_ground': False, 'velocity': 97.13, 'true_track': 97.92, 'vertical_rate': 5.85, 'sensors': None, 'barometric_altitude': 4206.24, 'transponder_code': '4267', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a339b4', 'callsign': 'DAL2901 ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -93.0028, 'latitude': 43.3987, 'geo_altitude': 9547.86, 'on_ground': False, 'velocity': 227.81, 'true_track': 348.54, 'vertical_rate': -5.2, 'sensors': None, 'barometric_altitude': 9098.28, 'transponder_code': '3521', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a73db7', 'callsign': 'N566FF  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -94.4349, 'latitude': 44.569, 'geo_altitude': 2682.24, 'on_ground': False, 'velocity': 113.67, 'true_track': 283.34, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 2575.56, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'a84c1e', 'callsign': 'N6336U  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -90.5186, 'latitude': 43.2641, 'geo_altitude': 1691.64, 'on_ground': False, 'velocity': 76.05, 'true_track': 158.99, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 1615.44, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ad6ecb', 'callsign': 'DAL1405 ', 'origin_country': 'United States', 'time_position': 1696272045, 'last_contact': 1696272046, 'longitude': -93.0709, 'latitude': 44.9518, 'geo_altitude': 2506.98, 'on_ground': False, 'velocity': 145.58, 'true_track': 293.76, 'vertical_rate': -9.75, 'sensors': None, 'barometric_altitude': 2385.06, 'transponder_code': '2310', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
# {'icao24': 'ac3beb', 'callsign': 'DAL1182 ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -92.8982, 'latitude': 44.2216, 'geo_altitude': 5486.4, 'on_ground': False, 'velocity': 214.47, 'true_track': 152.27, 'vertical_rate': 8.78, 'sensors': None, 'barometric_altitude': 5250.18, 'transponder_code': '3657', 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LARGE: 4>}
# {'icao24': 'a9116b', 'callsign': 'N6835H  ', 'origin_country': 'United States', 'time_position': 1696272009, 'last_contact': 1696272029, 'longitude': -94.5118, 'latitude': 43.5364, 'geo_altitude': 1882.14, 'on_ground': False, 'velocity': 60.7, 'true_track': 0.0, 'vertical_rate': 1.3, 'sensors': None, 'barometric_altitude': 1798.32, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.LIGHT: 2>}
# {'icao24': 'a780f8', 'callsign': 'N5829Q  ', 'origin_country': 'United States', 'time_position': 1696272046, 'last_contact': 1696272046, 'longitude': -95.1009, 'latitude': 45.7939, 'geo_altitude': 2819.4, 'on_ground': False, 'velocity': 66.74, 'true_track': 130.94, 'vertical_rate': 0.0, 'sensors': None, 'barometric_altitude': 2735.58, 'transponder_code': None, 'special_purpose_indicator': False, 'position_source': <PositionSource.ADSB: 0>, 'category': <AircraftCategory.NO_INFORMATION: 0>}
